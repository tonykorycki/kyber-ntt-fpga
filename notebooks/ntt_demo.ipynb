# %% [markdown]
# # NTT Polynomial Multiplication — PYNQ Demo
#
# This notebook runs on the PYNQ-Z2 board. It loads the NTT-mul overlay,
# sends polynomial coefficients to the hardware IP, and verifies the result
# against the Python golden model.

# %%
from pynq import Overlay, MMIO
import numpy as np
import sys
sys.path.append('../golden')
from ntt import negacyclic_mul

# %%
# Load the overlay (bitstream)
ol = Overlay('ntt_mul.bit')
ol?

# %%
# TODO: MMIO setup, write a[] and b[], trigger START, poll DONE, read c[]
# Compare against: negacyclic_mul(a, b, n, q)
